# %%
import pandas as pd

# %%
df = pd.read_csv("covid_19_clean_complete.csv")

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.drop(["Province/State"],axis=1,inplace=True)

# %%
df
# Out:
#               Country/Region        Lat       Long        Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953  2020-01-22          0
# 1                    Albania  41.153300  20.168300  2020-01-22          0
# 2                    Algeria  28.033900   1.659600  2020-01-22          0
# 3                    Andorra  42.506300   1.521800  2020-01-22          0
# 4                     Angola -11.202700  17.873900  2020-01-22          0
# ...                      ...        ...        ...         ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100  2020-07-27        865
# 49064                  Yemen  15.552727  48.516388  2020-07-27       1691
# 49065                Comoros -11.645500  43.333300  2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100  2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600  2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region
# ...

# %%
x = df['Country/Region'].value_counts()

# %%
y = df['Deaths'].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.barplot(x,y,data = df)
# Out:
# C:\Users\Arjun\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country/Region', ylabel='Deaths'>

# %%
x = df.sort_values(['Deaths'],ascending = False)

# %%
x
# Out:
#       Country/Region        Lat        Long        Date  Confirmed  Deaths  \
# 49030             US  40.000000 -100.000000  2020-07-27    4290259  148011
# 48769             US  40.000000 -100.000000  2020-07-26    4233923  146935
# 48508             US  40.000000 -100.000000  2020-07-25    4178970  146465
# 48247             US  40.000000 -100.000000  2020-07-24    4112531  145560
# 47986             US  40.000000 -100.000000  2020-07-23    4038816  144430
# ...              ...        ...         ...         ...        ...     ...
# 30889      Greenland  71.706900  -42.604300  2020-05-19         11       0
# 30888        Denmark  61.892600   -6.911800  2020-05-19        187       0
# 10428        Burundi  -3.373100   29.918900  2020-03-01          0       0
# 10429   Sierra Leone   8.460555  -11.779889  2020-03-01          0       0
# 0        Afghanistan  33.939110   67.709953  2020-01-22          0       0
#
#        Recovered   Active             WHO Region
# ...

# %%
x.head(10)
# Out:
#       Country/Region   Lat   Long        Date  Confirmed  Deaths  Recovered  \
# 49030             US  40.0 -100.0  2020-07-27    4290259  148011    1325804
# 48769             US  40.0 -100.0  2020-07-26    4233923  146935    1297863
# 48508             US  40.0 -100.0  2020-07-25    4178970  146465    1279414
# 48247             US  40.0 -100.0  2020-07-24    4112531  145560    1261624
# 47986             US  40.0 -100.0  2020-07-23    4038816  144430    1233269
# 47725             US  40.0 -100.0  2020-07-22    3970121  143316    1210849
# 47464             US  40.0 -100.0  2020-07-21    3899211  142121    1182018
# 47203             US  40.0 -100.0  2020-07-20    3834677  141025    1160087
# 46942             US  40.0 -100.0  2020-07-19    3773260  140534    1131121
# 46681             US  40.0 -100.0  2020-07-18    3711413  140119    1122720
#
#         Active WHO Region
# 49030  2816444   Americas
# 48769  2789125   Americas
# 48508  2753091   Americas
# ...

# %%
x.head(100)
# Out:
#       Country/Region     Lat      Long        Date  Confirmed  Deaths  \
# 49030             US  40.000 -100.0000  2020-07-27    4290259  148011
# 48769             US  40.000 -100.0000  2020-07-26    4233923  146935
# 48508             US  40.000 -100.0000  2020-07-25    4178970  146465
# 48247             US  40.000 -100.0000  2020-07-24    4112531  145560
# 47986             US  40.000 -100.0000  2020-07-23    4038816  144430
# ...              ...     ...       ...         ...        ...     ...
# 27628             US  40.000 -100.0000  2020-05-06    1233527   74851
# 45442         Brazil -14.235  -51.9253  2020-07-14    1926824   74133
# 45181         Brazil -14.235  -51.9253  2020-07-13    1884967   72833
# 27367             US  40.000 -100.0000  2020-05-05    1208271   72393
# 44920         Brazil -14.235  -51.9253  2020-07-12    1864681   72100
#
#        Recovered   Active WHO Region
# 49030    1325804  2816444   Americas
# 48769    1297863  2789125   Americas
# ...

# %%
x['Country/Region'].unique()
# Out:
# array(['US', 'Brazil', 'United Kingdom', 'Mexico', 'Italy', 'India',
#        'France', 'Spain', 'Peru', 'Iran', 'Russia', 'Belgium', 'Chile',
#        'Germany', 'Colombia', 'South Africa', 'Netherlands', 'Pakistan',
#        'Sweden', 'Canada', 'Turkey', 'Ecuador', 'Indonesia', 'Egypt',
#        'China', 'Iraq', 'Argentina', 'Bangladesh', 'Saudi Arabia',
#        'Bolivia', 'Romania', 'Switzerland', 'Philippines', 'Ireland',
#        'Guatemala', 'Portugal', 'Poland', 'Ukraine', 'Panama',
#        'Kyrgyzstan', 'Afghanistan', 'Honduras', 'Algeria',
#        'Dominican Republic', 'Japan', 'Nigeria', 'Moldova', 'Sudan',
#        'Austria', 'Armenia', 'Denmark', 'Hungary', 'Kazakhstan', 'Serbia',
#        'Belarus', 'Yemen', 'Israel', 'North Macedonia', 'Kuwait',
#        'Azerbaijan', 'El Salvador', 'Oman', 'Cameroon', 'Czechia',
#        'Bulgaria', 'United Arab Emirates', 'Finland', 'Morocco',
#        'South Korea', 'Bosnia and Herzegovina', 'Kenya', 'Norway',
# ...

# %%
x['Deaths'].sum()
# Out:
# 43384903

# %%
x1 = x[x['Country/Region'] == 'US']

# %%
x1
# Out:
#       Country/Region   Lat   Long        Date  Confirmed  Deaths  Recovered  \
# 49030             US  40.0 -100.0  2020-07-27    4290259  148011    1325804
# 48769             US  40.0 -100.0  2020-07-26    4233923  146935    1297863
# 48508             US  40.0 -100.0  2020-07-25    4178970  146465    1279414
# 48247             US  40.0 -100.0  2020-07-24    4112531  145560    1261624
# 47986             US  40.0 -100.0  2020-07-23    4038816  144430    1233269
# ...              ...   ...    ...         ...        ...     ...        ...
# 8053              US  40.0 -100.0  2020-02-21         15       0          5
# 8314              US  40.0 -100.0  2020-02-22         15       0          5
# 7792              US  40.0 -100.0  2020-02-20         13       0          3
# 9619              US  40.0 -100.0  2020-02-27         16       0          6
# 9880              US  40.0 -100.0  2020-02-28         16       0          7
#
#         Active WHO Region
# 49030  2816444   Americas
# ...

# %%
list = ['US', 'Brazil', 'United Kingdom', 'Mexico', 'Italy', 'India',
       'France', 'Spain', 'Peru', 'Iran','Colombia', 'South Africa', 'Netherlands', 'Pakistan',
       'Sweden', 'Canada', 'Turkey', 'Ecuador', 'Indonesia', 'Egypt',
       'China', 'Iraq', 'Argentina', 'Bangladesh', 'Saudi Arabia',
       'Bolivia', 'Romania', 'Switzerland', 'Philippines', 'Ireland',
       'Guatemala', 'Portugal']

# %%
for i in list:
    x1 = x[x['Country/Region'] == i]
    sumz = x1['Deaths'].sum()
    print(i,":",sumz)
    #matplotlib.pyplot.rcParams["figure.figsize"]
    plt.rcParams["figure.figsize"] = (50,15)
    plt.bar(i,sumz)
# Out:
# US : 11011411
# Brazil : 3938034
# United Kingdom : 3997775
# Mexico : 1728277
# Italy : 3707717
# India : 1111831
# France : 3048524
# Spain : 3033030
# Peru : 652113
# Iran : 1024136
# Colombia : 236525
# South Africa : 181979
# Netherlands : 622314
# Pakistan : 264729
# Sweden : 448913
# Canada : 699566
# Turkey : 466056
# Ecuador : 346618
# Indonesia : 220272
# Egypt : 186936
# China : 672413
# Iraq : 121392
# Argentina : 97749
# Bangladesh : 115633
# Saudi Arabia : 105150
# Bolivia : 78032
# Romania : 140031
# Switzerland : 207858
# Philippines : 110892
# Ireland : 161948
# Guatemala : 49133
# Portugal : 146603

# %%
x.sort_values('Deaths',ascending= False)[:10]
# Out:
#       Country/Region   Lat   Long        Date  Confirmed  Deaths  Recovered  \
# 49030             US  40.0 -100.0  2020-07-27    4290259  148011    1325804
# 48769             US  40.0 -100.0  2020-07-26    4233923  146935    1297863
# 48508             US  40.0 -100.0  2020-07-25    4178970  146465    1279414
# 48247             US  40.0 -100.0  2020-07-24    4112531  145560    1261624
# 47986             US  40.0 -100.0  2020-07-23    4038816  144430    1233269
# 47725             US  40.0 -100.0  2020-07-22    3970121  143316    1210849
# 47464             US  40.0 -100.0  2020-07-21    3899211  142121    1182018
# 47203             US  40.0 -100.0  2020-07-20    3834677  141025    1160087
# 46942             US  40.0 -100.0  2020-07-19    3773260  140534    1131121
# 46681             US  40.0 -100.0  2020-07-18    3711413  140119    1122720
#
#         Active WHO Region
# 49030  2816444   Americas
# 48769  2789125   Americas
# 48508  2753091   Americas
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(0)

# %%
x = np.random.rand(100,1)

# %%
y = 2+3*4 + np.random.rand(100,1)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
predict = model.predict(x)

# %%
plt.scatter(x,y,s=20)

# %%
plt.plot(x,predict)

# %%
plt.scatter(x,y,s=10)
plt.plot(x,predict)

# %%
df
# Out:
#               Country/Region        Lat       Long        Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953  2020-01-22          0
# 1                    Albania  41.153300  20.168300  2020-01-22          0
# 2                    Algeria  28.033900   1.659600  2020-01-22          0
# 3                    Andorra  42.506300   1.521800  2020-01-22          0
# 4                     Angola -11.202700  17.873900  2020-01-22          0
# ...                      ...        ...        ...         ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100  2020-07-27        865
# 49064                  Yemen  15.552727  48.516388  2020-07-27       1691
# 49065                Comoros -11.645500  43.333300  2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100  2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600  2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region
# ...

# %%
sns.barplot(x,y)
# Out:
# C:\Users\Arjun\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_core.py:1479, in categorical_order(vector, order)
#    1478 try:
# -> 1479     order = vector.cat.categories
#    1480 except (TypeError, AttributeError):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cat'
#
# ...

# %%
df = pd.read_csv('Software_Professional_Salaries.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 df = pd.read_csv('Software_Professional_Salaries.csv')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
