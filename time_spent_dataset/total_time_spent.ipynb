# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from matplotlib import rcParams

# %%
df = pd.read_csv('Time-Use-in-OECD-Countries-OECD.csv')

# %%
df
# Out:
#           Country                  Category  Time (minutes)
# 0       Australia                 Paid work             211
# 1         Austria                 Paid work             280
# 2         Belgium                 Paid work             194
# 3          Canada                 Paid work             269
# 4         Denmark                 Paid work             200
# ..            ...                       ...             ...
# 456            UK  Other leisure activities              98
# 457           USA  Other leisure activities              73
# 458         China  Other leisure activities              53
# 459         India  Other leisure activities             109
# 460  South Africa  Other leisure activities              82
#
# [461 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461 entries, 0 to 460
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         461 non-null    object
#  1   Category        461 non-null    object
#  2   Time (minutes)  461 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 10.9+ KB

# %%
df.head()
# Out:
#      Country   Category  Time (minutes)
# 0  Australia  Paid work             211
# 1    Austria  Paid work             280
# 2    Belgium  Paid work             194
# 3     Canada  Paid work             269
# 4    Denmark  Paid work             200

# %%
df.tail()
# Out:
#           Country                  Category  Time (minutes)
# 456            UK  Other leisure activities              98
# 457           USA  Other leisure activities              73
# 458         China  Other leisure activities              53
# 459         India  Other leisure activities             109
# 460  South Africa  Other leisure activities              82

# %%
df['Category'].value_counts()
# Out:
# Paid work                           33
# Education                           33
# Care for household members          33
# Housework                           33
# Shopping                            33
# Other unpaid work & volunteering    33
# Sleep                               33
# Eating and drinking                 33
# Personal care                       33
# Sports                              33
# Seeing friends                      33
# TV and Radio                        33
# Other leisure activities            33
# Attending events                    32
# Name: Category, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Australia       14
# Luxembourg      14
# India           14
# China           14
# USA             14
# UK              14
# Turkey          14
# Sweden          14
# Spain           14
# Slovenia        14
# Portugal        14
# Poland          14
# Norway          14
# New Zealand     14
# Netherlands     14
# Mexico          14
# Lithuania       14
# Austria         14
# Latvia          14
# Korea           14
# Italy           14
# Ireland         14
# Hungary         14
# Greece          14
# Germany         14
# France          14
# Finland         14
# Estonia         14
# Denmark         14
# Canada          14
# Belgium         14
# South Africa    14
# Japan           13
# Name: Country, dtype: int64

# %%
df_ind = df.loc[df['Country'] == 'India'].value_counts()

# %%
df_ind
# Out:
# Country  Category                          Time (minutes)
# India    Attending events                  5                 1
#          Care for household members        21                1
#          Eating and drinking               84                1
#          Education                         23                1
#          Housework                         148               1
#          Other leisure activities          109               1
#          Other unpaid work & volunteering  22                1
#          Paid work                         272               1
#          Personal care                     75                1
#          Seeing friends                    73                1
#          Shopping                          12                1
#          Sleep                             528               1
#          Sports                            5                 1
#          TV and Radio                      61                1
# dtype: int64

# %%
ax = sns.barplot(x="Category", y="Time (minutes)", data=df)

# %%
df.loc[df['Category'] == 'Paid work'].value_counts()
# Out:
# Country       Category   Time (minutes)
# Australia     Paid work  211               1
# Latvia        Paid work  317               1
# UK            Paid work  235               1
# Turkey        Paid work  217               1
# Sweden        Paid work  262               1
# Spain         Paid work  176               1
# South Africa  Paid work  189               1
# Slovenia      Paid work  227               1
# Portugal      Paid work  259               1
# Poland        Paid work  229               1
# Norway        Paid work  201               1
# New Zealand   Paid work  241               1
# Netherlands   Paid work  218               1
# Mexico        Paid work  302               1
# Luxembourg    Paid work  247               1
# Lithuania     Paid work  304               1
# Korea         Paid work  288               1
# Austria       Paid work  280               1
# Japan         Paid work  326               1
# Italy         Paid work  149               1
# ...

# %%
df_ind = df[df['Country'] == 'India']

# %%
df_ind
# Out:
#     Country                          Category  Time (minutes)
# 31    India                         Paid work             272
# 64    India                         Education              23
# 97    India       Care for household members               21
# 130   India                         Housework             148
# 163   India                          Shopping              12
# 196   India  Other unpaid work & volunteering              22
# 229   India                             Sleep             528
# 262   India               Eating and drinking              84
# 295   India                     Personal care              75
# 328   India                            Sports               5
# 360   India                  Attending events               5
# 393   India                    Seeing friends              73
# 426   India                      TV and Radio              61
# 459   India          Other leisure activities             109

# %%
rcParams['figure.figsize'] = 30,16
ax = sns.barplot(x="Category", y="Time (minutes)", data=df_ind)

# %%
df_ind['Category'].value_counts()
# Out:
# Paid work                           1
# Education                           1
# Care for household members          1
# Housework                           1
# Shopping                            1
# Other unpaid work & volunteering    1
# Sleep                               1
# Eating and drinking                 1
# Personal care                       1
# Sports                              1
# Attending events                    1
# Seeing friends                      1
# TV and Radio                        1
# Other leisure activities            1
# Name: Category, dtype: int64

# %%
df_usa = df[df['Country'] == 'USA']

# %%
df_usa
# Out:
#     Country                          Category  Time (minutes)
# 29      USA                         Paid work             251
# 62      USA                         Education              31
# 95      USA       Care for household members               31
# 128     USA                         Housework             100
# 161     USA                          Shopping              22
# 194     USA  Other unpaid work & volunteering              65
# 227     USA                             Sleep             528
# 260     USA               Eating and drinking              63
# 293     USA                     Personal care              57
# 326     USA                            Sports              18
# 358     USA                  Attending events               8
# 391     USA                    Seeing friends              44
# 424     USA                      TV and Radio             148
# 457     USA          Other leisure activities              73

# %%
rcParams['figure.figsize'] = 30,16
ax = sns.barplot(x="Category", y="Time (minutes)", data=df_usa)

# %%
df['Time (minutes)'].sum()
# Out:
# 47526

# %%
df_ind['Time (minutes)'].sum()
# Out:
# 1438

# %%
df['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'Estonia',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland',
#        'Italy ', 'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway ', 'Poland',
#        'Portugal', 'Slovenia', 'Spain', 'Sweden', 'Turkey', 'UK', 'USA',
#        'China', 'India', 'South Africa'], dtype=object)

# %%
list1 = ['Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'Estonia',
       'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland',
       'Italy ', 'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg',
       'Mexico', 'Netherlands', 'New Zealand', 'Norway ', 'Poland',
       'Portugal', 'Slovenia', 'Spain', 'Sweden', 'Turkey', 'UK', 'USA',
       'China', 'India', 'South Africa']

# %%
country =[]
time = []
for i in list1:
    df_ex = df[df['Country'] == i]
    country = country + [i]
    time = time + [df_ex['Time (minutes)'].sum()]
    data = {'Country':country,'time':time}
df_time = pd.DataFrame(data)
df_time
# Out:
#          Country  time
# 0      Australia  1440
# 1        Austria  1442
# 2        Belgium  1441
# 3         Canada  1440
# 4        Denmark  1440
# 5        Estonia  1441
# 6        Finland  1440
# 7         France  1441
# 8        Germany  1440
# 9         Greece  1439
# 10       Hungary  1440
# 11       Ireland  1440
# 12        Italy   1441
# 13         Japan  1464
# 14         Korea  1439
# 15        Latvia  1440
# 16     Lithuania  1440
# 17    Luxembourg  1437
# 18        Mexico  1438
# 19   Netherlands  1442
# 20   New Zealand  1442
# 21       Norway   1440
# 22        Poland  1439
# 23      Portugal  1440
# 24      Slovenia  1441
# 25         Spain  1441
# 26        Sweden  1433
# 27        Turkey  1442
# 28            UK  1438
# 29           USA  1439
# 30         China  1441
# 31         India  1438
# 32  South Africa  1427

# %%
sns.barplot(x="Country", y="time", data=df_time)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='time'>
